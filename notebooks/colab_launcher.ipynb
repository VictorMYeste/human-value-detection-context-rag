# %% [markdown]
# # Colab Launcher
#
# Use this notebook to run project scripts from Google Colab.
#
# 1. Mount Google Drive.
# 2. Set `PROJECT_ROOT` to your repo location.
# 3. Install requirements.
# 4. Run any script.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
# TODO: update this path to match your Drive location
PROJECT_ROOT = '/content/drive/MyDrive/path/to/human-value-detection-context-rag'
os.chdir(PROJECT_ROOT)
print('Working dir:', os.getcwd())
# TODO: update HF_TOKEN to have access to HuggingFace
os.environ["HF_TOKEN"] = ""

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## Run a script
#
# Examples:
# - Train DeBERTa:
#   `!python scripts/train_deberta.py --config configs/deberta_sentence.yaml --seed 42 --eval`
# - Run Gemma:
#   `!python scripts/run_gemma.py --config configs/gemma_sentence.yaml --eval`

# %%
# Example command (edit as needed)
# !python scripts/train_deberta.py --config configs/deberta_sentence.yaml --seed 42 --eval > results/logs/deberta_sentence_no_rag_seed42.log 2>&1 &
# !tail -f results/logs/deberta_sentence_no_rag_seed42.log

# %%
# Kill all running training processes (use with caution)
# !kill -9 $(pgrep -f train_deberta.py)
